# %%
import pandas as pd
import numpy as np
import csv
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
import matplotlib as plt

print("1.Blues 2.Classical 3.Country 4.Disco 5.Pop 6.Jazz 7.Rock 8.Metal")
x= input("Please tell us the genere of the songs you like from the above options " )
genre_u=x.lower()
print(genre_u)

print("1.Beatrice Jones 2.Kurt Morgan 3.Shawn Reyes 4.Byron Pena 5.Jamie Owens 6.Kristine Padilla 7.Ada Farmer ")

y=input("Please tell us a singer you may like from above or you can add your favorite singer " )
artist_u=y.lower()
print(artist_u)

data_1 = pd.read_csv("C:/Users/dharm/Documents/songsDataset.csv/Book1.csv",header=0,usecols=['genre','artist'])
print(data_1)

a=data_1.values.tolist()



for i in range(len(a)):
    if(a[i][0]==genre_u and a[i][1]==artist_u):
        a[i].append(2)
        
    elif(a[i][0]==genre_u):
        a[i].append(1)
        
       
    elif(a[i][1]==artist_u):
        a[i].append(1)
       
    else:
        a[i].append(0)
        
    i+=1
    

a.sort(key=lambda x:x[2],reverse=True)    
                 
print(a)    

recommended= a[:10]

print("\nWe recommend you the following songs")

print(recommended)
# Out:
# 1.Blues 2.Classical 3.Country 4.Disco 5.Pop 6.Jazz 7.Rock 8.Metal
# Please tell us the genere of the songs you like from the above options Metal
# metal
# 1.Beatrice Jones 2.Kurt Morgan 3.Shawn Reyes 4.Byron Pena 5.Jamie Owens 6.Kristine Padilla 7.Ada Farmer
# Please tell us a singer you may like from above or you can add your favorite singer Kurt Morgan
# kurt morgan
#         genre            artist
# 0       blues    beatrice jones
# 1   classical       kurt morgan
# 2       disco       shawn reyes
# 3         pop        byron pena
# 4        jazz       kurt morgan
# 5        rock    beatrice jones
# 6       metal       kurt morgan
# 7       metal       shawn reyes
# 8       disco       jamie owens
# 9         pop        byron pena
# 10  classical    beatrice jones
# 11      blues  kristine padilla
# 12       rock       shawn reyes
# 13       jazz       kurt morgan
# 14      metal    beatrice jones
# 15       rock  kristine padilla
# 16      blues        byron pena
# ...

# %%
import pandas as pd
import numpy as np
import csv
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
import matplotlib as plt
data = pd.read_csv("C:/Users/dharm/Documents/songsDataset.csv/songsDataset.csv")
print(data.head(10))


y = data.iloc[:,-1]
X = data.iloc[:,0:2]


X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=1)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
print("\nX_train:\n")
print(X_train)

print("\nX_test:\n")
print(X_test)


y_train[y_train == 0] = -1
y_train[y_train == 1] = 0
y_train[y_train == 2] = 0
y_train[y_train >= 3] = 1


y_test[y_test == 0] = -1
y_test[y_test == 1] = 0
y_test[y_test == 2] = 0
y_test[y_test >= 3] = 1
# Out:
#    'userID'  'songID'  'rating'
# 0         0      7171         5
# 1         0      8637         4
# 2         0     21966         4
# 3         0     35821         5
# 4         0     82446         5
# 5         0     90409         5
# 6         0    107410         5
# 7         0    131919         5
# 8         0    132685         3
# 9         0    136507         3
#
# X_train:
#
# [[ 92741 112472]
#  [148866  91496]
#  [ 46935   7276]
#  ...
#  [ 47092  54471]
#  [ 49175  72017]
#  [ 12803  79804]]
#
# X_test:
#
# [[180639  91888]
#  [ 42284 128710]
#  [177271 108885]
#  ...
#  [  2574 117515]
#  [ 87783  34199]
#  [194492 122112]]

# %%
classifier = GaussianNB()

# train
classifier.fit(X_train, y_train)
#predict
predictions = classifier.predict(X_test)

print("The accuracy of our system is:")
print(accuracy_score(y_test, predictions)*100)
# Out:
# The accuracy of our system is:
# 70.60583333333334
